# %%
import seaborn as sns

# Load Titanic dataset directly from seaborn
df = sns.load_dataset("titanic")
print(df.head())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
##HOW BIG IS THE DATA
df.shape
# Out:
# (891, 15)

# %%
##HOW DOES DATA LOOK
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df.sample(5)
# Out:
#      survived  pclass     sex    age  sibsp  parch     fare embarked   class  \
# 755         1       2    male   0.67      1      1  14.5000        S  Second
# 579         1       3    male  32.00      0      0   7.9250        S   Third
# 28          1       3  female    NaN      0      0   7.8792        Q   Third
# 434         0       1    male  50.00      1      0  55.9000        S   First
# 211         1       2  female  35.00      0      0  21.0000        S  Second
#
#        who  adult_male deck  embark_town alive  alone
# 755  child       False  NaN  Southampton   yes  False
# 579    man        True  NaN  Southampton   yes   True
# 28   woman       False  NaN   Queenstown   yes   True
# 434    man        True    E  Southampton    no  False
# 211  woman       False  NaN  Southampton   yes   True

# %%
##HOW columns look like
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
##are there any missing values
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
##how does data look mathematical
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
##are there duplicate values
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
##how is the correlation between cols
# First, identify numeric columns only for correlation
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation only on numeric columns
numeric_df.corr()

# Alternative approach: If you want to include categorical columns like 'male'
# You need to convert them to numeric values first using one-hot encoding
# df_encoded = pd.get_dummies(df)
# df_encoded.corr()
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
##EDA:TO UNDERSTAND DATA FULLY:UNIVARIATE ANALYLSIS:
import pandas as pd
df1=pd.read_csv("Titanic-Dataset.csv")

# %%
df1.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
##categorical data
##count plot
sns.countplot(x='Survived', data=df1)
df1['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
sns.countplot(x='Pclass', data=df1)
df1['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
sns.countplot(x='Embarked', data=df1)
df1['Embarked'].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
##b)Pie chart
df1['Survived'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df1['Sex'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
##@. numerical data
##histogram
import matplotlib.pyplot as plt
plt.hist(df['age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df1["Age"])##also show skenewss
# Out:
# C:\Users\Sejal Jain\AppData\Local\Temp\ipykernel_10972\2503459887.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
##boxplot
sns.boxplot(df1["Fare"])
# Out:
# <Axes: ylabel='Fare'>

# %%
##500 dollars is way more than others

# %%
sns.boxplot(df1["Age"])
# Out:
# <Axes: ylabel='Age'>

# %%
#min and max
df1["Age"].min()
# Out:
# 0.42

# %%
df1["Age"].max()
# Out:
# 80.0

# %%
df1["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
df1["Age"].skew()
# Out:
# np.float64(0.38910778230082704)

# %%
##harry potter data univarate anaylsis
df3=pd.read_csv("Charater_Set.csv")
df3.shape
# Out:
# (124, 9)

# %%
df3.head()
# Out:
#    SNO              Name       House              Role  \
# 0    1      Harry Potter  Gryffindor  Main Protagonist
# 1    2  Hermione Granger  Gryffindor  Main Protagonist
# 2    3       Ron Weasley  Gryffindor  Main Protagonist
# 3    4      Draco Malfoy   Slytherin        Antagonist
# 4    5  Albus Dumbledore  Gryffindor        Headmaster
#
#                Notable Traits           Birthdate Blood Status  \
# 0           Courageous, Loyal       July 31, 1980   Half-Blood
# 1          Intelligent, Brave  September 19, 1979  Muggle-born
# 2                Loyal, Funny       March 1, 1980   Pure-blood
# 3  Ambitious, Proud, Arrogant        June 5, 1980   Pure-blood
# 4   Wise, Kind, Compassionate                1881   Half-blood
#
#                Patronus    Wand Core
# 0                  Stag   Holly, 11"
# 1                 Otter   Vine, 10¾"
# 2  Jack Russell Terrier  Willow, 14"
# 3               Unknown     Elm, 10"
# 4               Phoenix   Elder, 15"

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   SNO             124 non-null    int64
#  1   Name            124 non-null    object
#  2   House           97 non-null     object
#  3   Role            124 non-null    object
#  4   Notable Traits  124 non-null    object
#  5   Birthdate       124 non-null    object
#  6   Blood Status    123 non-null    object
#  7   Patronus        124 non-null    object
#  8   Wand Core       124 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 8.8+ KB

# %%
df3.isnull().sum()
# Out:
# SNO                0
# Name               0
# House             27
# Role               0
# Notable Traits     0
# Birthdate          0
# Blood Status       1
# Patronus           0
# Wand Core          0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# np.int64(0)

# %%
df3.describe()##useless since only one numerical column that also sr no.
# Out:
#               SNO
# count  124.000000
# mean    62.500000
# std     35.939764
# min      1.000000
# 25%     31.750000
# 50%     62.500000
# 75%     93.250000
# max    124.000000

# %%
df3.corr()##no numerical data so no usefull
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df3.corr()
#
# File C:\Users\Public\anaconda3\Lib\site-packages\pandas\core\frame.py:11076, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11074 cols = data.columns
#   11075 idx = cols.copy()
# > 11076 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11078 if method == "pearson":
#   11079     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File C:\Users\Public\anaconda3\Lib\site-packages\pandas\core\frame.py:2002, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    2000 if dtype is not None:
#    2001     dtype = np.dtype(dtype)
# -> 2002 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    2003 if result.dtype is not dtype:
#    2004     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
##categorical data
##countplot
sns.countplot(x="House",data=df3)
df3["House"].value_counts()
# Out:
# House
# Gryffindor              43
# Slytherin               26
# Ravenclaw               14
# Hufflepuff               9
# Weasley (Gryffindor)     2
# Durmstrang               2
# Beauxbatons              1
# Name: count, dtype: int64

# %%
sns.countplot(x="Role",data=df3)
df3["Role"].value_counts()
# Out:
# Role
# Student                        6
# Main Protagonist               3
# Quidditch Player               3
# Ministry Employee              2
# Death Eater, Professor         2
#                               ..
# Champion, Student              1
# Student, Quidditch Player      1
# Journalist                     1
# Father of Harry Potter         1
# Founder of Gryffindor House    1
# Name: count, Length: 103, dtype: int64

# %%
##pie chart
df3['House'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(y='Patronus', data=df3)
# Out:
# <Axes: xlabel='count', ylabel='Patronus'>

# %%
sns.countplot(x='Blood Status', data=df3)
df3["Blood Status"].value_counts()
# Out:
# Blood Status
# Pure-blood                53
# Muggle-born               33
# Half-blood                18
# Unknown                   14
# Half-giant                 2
# Half-Blood                 1
# Half-giant, Half-blood     1
# Squib                      1
# Name: count, dtype: int64

# %%
##avg wang length
df3['WandLength'] = df3['Wand Core'].str.extract('(\d+)').astype(float)

sns.histplot(df3['WandLength'], kde=True)
# Out:
# <Axes: xlabel='WandLength', ylabel='Count'>
