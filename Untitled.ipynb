# %%
import pandas as pd

# %%
df=pd.read_csv("Titanic-Dataset.csv")

# %%
df.head()

# %%
# !pip install ydata-profiling

# %%
# Then import and use it
from ydata_profiling import ProfileReport
# or if you're using an older version that still uses pandas_profiling
# !pip install pandas-profiling
# from pandas_profiling import ProfileReport

prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Then import and use it
# ----> 2 from ydata_profiling import ProfileReport
#       3 # or if you're using an older version that still uses pandas_profiling
#       4 # !pip install pandas-profiling
#       5 # from pandas_profiling import ProfileReport
#       7 prof = ProfileReport(df)
#
# ModuleNotFoundError: No module named 'ydata_profiling'
