# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=["Class label","Alcohol","Malic acid"]

# %%
df
# Out:
#      Class label  Alcohol Malic acid
# 0         178.00    13.00    class_0
# 1          14.23     1.71       2.43
# 2          13.20     1.78       2.14
# 3          13.16     2.36       2.67
# 4          14.37     1.95        2.5
# ..           ...      ...        ...
# 174        13.71     5.65       2.45
# 175        13.40     3.91       2.48
# 176        13.27     4.28       2.26
# 177        13.17     2.59       2.37
# 178        14.13     4.10       2.74
#
# [179 rows x 3 columns]

# %%
sns.kdeplot(df['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
# First, ensure 'Malic acid' is numeric
df['Malic acid'] = pd.to_numeric(df['Malic acid'], errors='coerce')

# Then create the KDE plot
sns.kdeplot(df['Malic acid'])

# If there are NaN values after conversion, you might want to drop them
# sns.kdeplot(df['Malic acid'].dropna())
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>

# %%
color_dict={1:'red',3:'green',2:'blue'}
# Fix: Use x and y as keyword arguments instead of positional arguments
sns.scatterplot(x=df['Alcohol'], y=df['Malic acid'], hue=df['Class label'], palette=color_dict)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 color_dict={1:'red',3:'green',2:'blue'}
#       2 # Fix: Use x and y as keyword arguments instead of positional arguments
# ----> 3 sns.scatterplot(x=df['Alcohol'], y=df['Malic acid'], hue=df['Class label'], palette=color_dict)
#
# File C:\Users\Public\anaconda3\Lib\site-packages\seaborn\relational.py:621, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
#     615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
# ...

# %%
# First, make sure seaborn is imported
import seaborn as sns
import pandas as pd
import numpy as np

# Assuming df is your DataFrame with the wine dataset
# If df is not defined, you need to load your data first
# For example:
# df = pd.read_csv('wine_data.csv')  # Uncomment and modify path as needed

# Check if the DataFrame has the required columns
# If column names are different, adjust accordingly
if 'Alcohol' in df.columns and 'Malic acid' in df.columns and 'Class label' in df.columns:
    # Create the color dictionary for the palette
    color_dict = {1: 'red', 2: 'blue', 3: 'green'}
    
    # Create the scatterplot with proper keyword arguments
    sns.scatterplot(x=df['Alcohol'], y=df['Malic acid'], 
                   hue=df['Class label'], palette=color_dict)
else:
    # Print available columns to help diagnose the issue
    print("Available columns:", df.columns.tolist())
    print("Please check column names in your DataFrame")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 18
#      15     color_dict = {1: 'red', 2: 'blue', 3: 'green'}
#      17     # Create the scatterplot with proper keyword arguments
# ---> 18     sns.scatterplot(x=df['Alcohol'], y=df['Malic acid'],
#      19                    hue=df['Class label'], palette=color_dict)
#      20 else:
#      21     # Print available columns to help diagnose the issue
#      22     print("Available columns:", df.columns.tolist())
#
# File C:\Users\Public\anaconda3\Lib\site-packages\seaborn\relational.py:621, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)    612     **kwargs
#     613 ):
# ...
